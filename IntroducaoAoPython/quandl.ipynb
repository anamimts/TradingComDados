# %% [markdown]
# ## Tutorial da biblioteca QUANDL - https://data.nasdaq.com/
# ### Quandl agora é NASDAQ DATA LINK
#
#
# - Para consultas de séries temporais dentro do BCB: https://www3.bcb.gov.br/sgspub/localizarseries/localizarSeries.do?method=prepararTelaLocalizarSeries
# - https://dadosabertos.bcb.gov.br/
# - https://pypi.org/project/ipeadatapy/

# %%
# !pip install quandl

# %%
import quandl
import pandas as pd

# %%
quandl.ApiConfig.api_key = 'civJaHaWaEpi7TBSHaRB'

# %%
cesta_basica_sp = quandl.get('BCB/7493', start_date='2021-01-01')

# %%
cesta_basica_sp.head()
# Out:
#              Value
# Date
# 2021-01-31  654.15
# 2021-02-28  639.47
# 2021-03-31  626.00
# 2021-04-30  632.61
# 2021-05-31  636.40

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
plt.plot(cesta_basica_sp)

# %% [markdown]
# ## Obtencao de dados

# %% [markdown]
# ## SELIC

# %%
selic = quandl.get("BCB/11")

# %%
selic.shape
# Out:
# (8972, 1)

# %%
selic.head()
# Out:
#                Value
# Date
# 1986-06-04  0.065041
# 1986-06-05  0.067397
# 1986-06-06  0.066740
# 1986-06-09  0.068247
# 1986-06-10  0.067041

# %%
selic.plot()

# %%
selic = quandl.get("BCB/11", start_date=' 2010-01-01')

# %%
selic.plot();

# %% [markdown]
# ## IPCA

# %%
ipca = quandl.get("BCB/13522", start_date = '2010-01-01')

# %%
ipca.plot()

# %% [markdown]
# ## CDI

# %%
cdi = quandl.get("BCB/12", start_date = '2010-01-01')

# %%
cdi.plot()

# %%
cdi_m = quandl.get("BCB/4391", start_date = '2010-01-01')

# %%
cdi_m.plot()

# %% [markdown]
# ## Cotacao do Dolar

# %%
dolar = quandl.get("BCB/10813", start_date='2010-01-01')

# %%
dolar.plot()

# %% [markdown]
# ## PIB - Produto Interno Bruto

# %%
pib_usd = quandl.get('ODA/BRA_NGDPD', start_date='2000-01-01')

# %%
pib_usd.head()
# Out:
#               Value
# Date
# 2000-12-31  655.435
# 2001-12-31  559.962
# 2002-12-31  509.358
# 2003-12-31  557.681
# 2004-12-31  668.432

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
plt.plot(pib_usd)
